# %% [markdown]
# # Modelagem
#
# ## Objetivo
# Treinar modelos de classificação para prever clientes adimplentes (`DEFAULT=0`) e inadimplentes (`DEFAULT=1`) usando Random Forest e Logistic Regression.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, make_scorer, classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
import joblib

# %% [markdown]
# ## Preparação dos dados
# - Carregando dados processados (`x_train`, `x_test`, `y_train`, `y_test`)
# - Aplicando SMOTE para balancear as classes no conjunto de treino

# %%
x_train = pd.read_csv("data/processed/x_train.csv")
x_test = pd.read_csv("data/processed/x_test.csv")

y_train = pd.read_csv("data/processed/y_train.csv").values.ravel()
y_test = pd.read_csv("data/processed/y_test.csv").values.ravel()

# %%
smote = SMOTE(random_state=42)
x_res, y_res = smote.fit_resample(x_train, y_train)

# %% [markdown]
# ## Cross-Validation e GridSearch, Treinamento e Salvamento dos Modelos
# - Utilizando `StratifiedKFold` para validação cruzada estratificada
# - Ajustando hiperparâmetros com `GridSearchCV`
# - Métrica de avaliação: F1-Score Macro (foco em desempenho geral)
# - Random Forest e Logistic Regression
# - Salvando os melhores modelos usando `joblib` para reutilização

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
f1_macro = make_scorer(f1_score, average='macro')

# %%
rf_param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None],
    'random_state': [42]
}

rf_grid = GridSearchCV(RandomForestClassifier(n_jobs=-1), rf_param_grid, scoring=f1_macro, cv=cv, n_jobs=-1, verbose=2)
rf_grid.fit(x_res, y_res)
rf_best = rf_grid.best_estimator_
print("\nMelhores parâmetros RF:", rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   4.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   7.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=   9.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  12.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   6.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  15.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  16.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  16.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   8.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   9.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  10.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  12.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  12.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   7.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  13.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   9.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  10.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  16.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  18.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  13.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  10.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  14.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   7.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   8.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  17.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   8.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  17.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  19.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  10.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  12.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  17.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  17.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  12.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  12.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  19.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  11.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  19.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  12.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  13.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  12.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  13.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  15.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   8.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   9.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  10.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  20.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  11.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  11.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  11.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  13.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  15.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  16.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  16.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  10.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  10.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   8.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  13.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  14.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  14.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  16.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  16.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   9.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   9.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  10.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  18.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  12.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  10.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  14.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   8.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  15.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   9.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  19.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  11.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  10.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  17.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  14.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  20.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  12.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  12.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  14.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  14.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  15.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  17.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  10.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  10.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  12.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  12.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  13.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  12.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  14.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  14.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  15.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  10.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  13.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  14.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  12.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   8.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   8.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  13.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  17.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  16.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  16.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  18.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   9.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  14.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  13.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  12.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  13.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  13.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  15.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  17.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  18.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  18.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  10.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  13.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  13.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  10.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  10.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   5.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   8.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  15.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=   8.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   4.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  20.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  13.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=   9.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  20.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  14.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  10.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   8.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   9.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   8.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  13.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   8.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  17.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   4.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  10.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  19.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   9.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  10.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   9.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  11.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   4.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  11.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  13.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  14.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   8.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  17.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  18.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   8.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  10.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  13.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  14.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  15.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  16.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   8.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   9.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  17.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   9.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   9.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   4.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  13.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  14.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   7.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  10.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  19.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  10.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  19.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  20.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  13.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  15.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  17.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=  12.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  13.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=  16.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  19.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=  16.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  21.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=  17.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  20.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=  15.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  28.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=  15.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  29.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=  18.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=  17.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  31.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  28.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=  19.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=  19.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  31.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  44.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  37.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  23.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  20.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  49.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  53.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  50.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  51.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  11.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  32.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  10.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  35.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  35.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  40.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  41.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  19.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  20.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  51.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  20.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  52.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  29.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  13.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  17.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  57.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  34.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  19.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  38.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  13.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  16.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  38.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  47.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  44.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  44.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  47.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  53.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  33.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  19.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  35.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  34.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  13.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  39.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  12.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  14.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  40.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  42.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  19.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  48.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  50.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  56.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  48.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  17.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  18.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  31.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  33.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  33.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  31.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  32.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  40.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  24.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  23.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  45.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  43.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  45.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  44.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  24.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  20.6s
# ...
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  48.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  43.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  19.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  26.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  35.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  47.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  30.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  22.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  58.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  57.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.2min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  35.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  40.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  17.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  48.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  33.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  18.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  46.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.5min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  29.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  52.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  29.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  38.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  36.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  24.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  44.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  26.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  47.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  31.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  39.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  48.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  50.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  27.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  30.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  54.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  41.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.2min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  41.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  29.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  52.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  26.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  30.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  32.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  57.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  56.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  24.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  58.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  26.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  22.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  47.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  49.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  23.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  44.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  44.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  46.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  24.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  24.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  43.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time= 1.2min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  22.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  42.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  45.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  46.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  47.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  25.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  25.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  24.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  22.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.2min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  42.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  24.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  44.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  43.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  44.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  45.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  23.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  24.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  21.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  23.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.2min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  41.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  42.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  38.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  41.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  41.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  42.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  31.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  43.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  34.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  34.7s
#
# Melhores parâmetros RF: {'max_depth': 15, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300, 'random_state': 42}

# %%
joblib.dump(rf_best, "models/rf.pkl")
# Out:
# ['models/rf.pkl']

# %%
lr_param_grid = {
    'C': [0.01, 0.1, 1, 10],
    'solver': ['lbfgs','liblinear'],
    'max_iter': [1000],
    'random_state': [42]
}

lr_grid = GridSearchCV(LogisticRegression(), lr_param_grid, scoring=f1_macro, cv=cv, n_jobs=-1, verbose=2)
lr_grid.fit(x_res, y_res)
lr_best = lr_grid.best_estimator_
print("\nMelhores parâmetros LR:", lr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s[CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
#
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.1s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.1s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.1s
#
# Melhores parâmetros LR: {'C': 0.01, 'max_iter': 1000, 'random_state': 42, 'solver': 'lbfgs'}

# %%
joblib.dump(lr_best, "models/lr.pkl")
# Out:
# ['models/lr.pkl']

# %% [markdown]
# ## Avaliação no Conjunto de Treino
# - Relatórios de classificação e matrizes de confusão para verificar o desempenho nos dados usados para treinar

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Random Forest
rf_pred_train = rf_best.predict(x_res)
print("\nRandom Forest - Classification Report (Treino)")
print(classification_report(y_res, rf_pred_train))
print("Confusion Matrix (Treino):")
print(confusion_matrix(y_res, rf_pred_train))

# Logistic Regression
lr_pred_train = lr_best.predict(x_res)
print("\nLogistic Regression - Classification Report (Treino)")
print(classification_report(y_res, lr_pred_train))
print("Confusion Matrix (Treino):")
print(confusion_matrix(y_res, lr_pred_train))
# Out:
# Random Forest - Classification Report (Treino)
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93     17402
#            1       0.92      0.94      0.93     17402
#
#     accuracy                           0.93     34804
#    macro avg       0.93      0.93      0.93     34804
# weighted avg       0.93      0.93      0.93     34804
#
# Confusion Matrix (Treino):
# [[16034  1368]
#  [ 1127 16275]]
#
# Logistic Regression - Classification Report (Treino)
#               precision    recall  f1-score   support
#
#            0       0.67      0.83      0.74     17402
#            1       0.77      0.59      0.67     17402
#
#     accuracy                           0.71     34804
#    macro avg       0.72      0.71      0.70     34804
# weighted avg       0.72      0.71      0.70     34804
#
# Confusion Matrix (Treino):
# [[14372  3030]
#  [ 7177 10225]]

# %% [markdown]
# ## Avaliação no Conjunto de Teste
# - Avaliando a capacidade de generalização dos modelos

# %%
# Random Forest - Teste
rf_pred_test = rf_best.predict(x_test)
print("\nRandom Forest - Classification Report (Teste)")
print(classification_report(y_test, rf_pred_test))
print("Confusion Matrix (Teste):")
print(confusion_matrix(y_test, rf_pred_test))

# Logistic Regression - Teste
lr_pred_test = lr_best.predict(x_test)
print("\nLogistic Regression - Classification Report (Teste)")
print(classification_report(y_test, lr_pred_test))
print("Confusion Matrix (Teste):")
print(confusion_matrix(y_test, lr_pred_test))
# Out:
# Random Forest - Classification Report (Teste)
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85      4350
#            1       0.49      0.56      0.52      1264
#
#     accuracy                           0.77      5614
#    macro avg       0.68      0.70      0.69      5614
# weighted avg       0.78      0.77      0.78      5614
#
# Confusion Matrix (Teste):
# [[3623  727]
#  [ 559  705]]
#
# Logistic Regression - Classification Report (Teste)
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.85      4350
#            1       0.49      0.57      0.53      1264
#
#     accuracy                           0.77      5614
#    macro avg       0.68      0.70      0.69      5614
# weighted avg       0.78      0.77      0.77      5614
#
# Confusion Matrix (Teste):
# [[3588  762]
#  [ 542  722]]
