# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_score, recall_score, accuracy_score, make_scorer
from sklearn.feature_selection import SelectKBest, f_classif
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import joblib
import os

# %%
x_train_full = pd.read_csv("data/processed/x_train.csv")
y_train_full = pd.read_csv("data/processed/y_train.csv")
y = y_train_full.values.ravel()

# %%
selector = SelectKBest(score_func=f_classif, k=12)
selector.fit(x_train_full, y)
top_features = x_train_full.columns[selector.get_support()]
print(top_features)
# Out:
# Index(['LIMIT_BAL', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6',
#        'sum_all_pay', 'bill_to_limit_ratio', 'pay_to_bill_ratio',
#        'avg_pay_delay', 'count_delays'],
#       dtype='object')

# %%
x = x_train_full[top_features]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.2, random_state=42)

# %%
smote = SMOTE(random_state=42)
x_res, y_res = smote.fit_resample(x_train, y_train)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_res)
x_test = scaler.transform(x_test)

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
f1 = make_scorer(f1_score, pos_label=0)

# %%
rf_param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None],
    'random_state': [42]
}

rf_grid = GridSearchCV(
    RandomForestClassifier(n_jobs=-1), rf_param_grid,
    scoring=f1, cv=cv, n_jobs=-1, verbose=2
)
rf_grid.fit(x_train, y_res)
rf_best = rf_grid.best_estimator_
print("\nMelhores parâmetros RF:", rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   2.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.5s[CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   3.6s
#
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   4.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   2.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   5.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=   7.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=   8.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=   7.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=   4.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   4.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=   9.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=   6.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=   7.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   6.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  10.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=   6.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   4.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=   8.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=   8.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=   7.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   4.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=   9.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=   9.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=   9.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=   9.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   5.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   6.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=   8.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   4.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   5.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  10.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   6.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=   9.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   7.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=   7.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=   7.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=   8.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   4.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   4.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=   5.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=   6.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=   9.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   4.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   7.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  11.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  10.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   8.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   7.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=   6.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   5.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   5.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  10.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  10.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=   9.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   4.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   6.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   6.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   5.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=   5.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   8.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   2.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   2.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=   9.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=   9.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   5.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  10.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=   4.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=   6.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   1.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=   7.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=   8.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   6.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   6.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   5.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  12.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   4.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  10.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  11.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   7.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=   6.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   2.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   2.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=   6.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   4.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   4.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=   9.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  10.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   7.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=   5.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   7.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=   8.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=   8.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=   8.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   4.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   7.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=   5.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   3.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   3.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   3.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   8.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  10.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   4.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=   4.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  11.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   3.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=   5.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   2.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   8.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  12.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   4.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   4.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=   7.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   3.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   4.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   5.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   5.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  10.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.2s[CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  10.8s
#
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   4.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=   7.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=   9.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   4.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   6.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  10.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  10.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=   5.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   7.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=   8.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=   9.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  12.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  12.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   8.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  13.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   8.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=  10.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  14.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  15.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  19.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  15.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  21.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   8.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  21.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  21.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  23.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  13.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  15.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  14.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  15.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  19.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  10.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  21.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  19.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  11.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  23.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  14.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  15.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  26.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  16.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  17.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  15.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  20.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  18.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  23.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  23.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  14.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  15.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  16.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   9.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  13.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  13.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  22.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  13.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  24.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  23.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  24.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  16.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  25.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  10.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   8.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  17.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   9.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   8.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  22.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  22.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  22.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  22.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  25.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  15.0s
# ...
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  40.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  41.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  26.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  27.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  26.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  28.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  16.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  13.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  15.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  16.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  38.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  39.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  42.0s[CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  41.4s
#
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  42.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  24.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  23.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  23.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  27.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  25.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  18.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  15.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  16.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  13.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  15.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  33.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  37.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  21.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  43.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  27.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  15.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  25.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  28.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  44.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  13.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  44.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  13.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  29.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  11.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  15.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  33.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  41.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  40.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  38.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  41.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  25.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  25.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  17.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  13.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  27.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  27.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  26.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  13.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  15.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  16.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  36.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  38.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  37.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  42.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  23.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  40.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  20.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  29.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  17.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  13.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  15.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  14.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  11.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  31.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  31.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  33.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  37.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  34.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  35.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  21.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  12.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  24.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  24.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  43.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  14.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  27.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  15.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  19.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  28.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  33.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  18.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  34.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  23.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  22.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  23.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  26.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  41.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  40.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  12.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  43.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  29.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  15.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   8.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  12.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  14.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  39.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  39.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  33.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  24.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  23.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  40.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  26.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  25.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  40.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  26.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  24.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  26.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  25.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  25.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  23.6s
#
# Melhores parâmetros RF: {'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300, 'random_state': 42}

# %%
joblib.dump(rf_best, "models/rf.pkl")
# Out:
# ['models/rf.pkl']

# %%
lr_param_grid = {
    'C': [0.01, 0.1, 1, 10],
    'solver': ['lbfgs','liblinear'],
    'max_iter': [1000],
    'random_state': [42]
}

lr_grid = GridSearchCV(
    LogisticRegression(), lr_param_grid,
    scoring=f1, cv=cv, n_jobs=-1, verbose=2
)
lr_grid.fit(x_train, y_res)
lr_best = lr_grid.best_estimator_
print("\nMelhores parâmetros LR:", lr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s[CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
#
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.3s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.4s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.4s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.2s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.4s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
#
# Melhores parâmetros LR: {'C': 1, 'max_iter': 1000, 'random_state': 42, 'solver': 'liblinear'}

# %%
joblib.dump(lr_best, "models/lr.pkl")
# Out:
# ['models/lr.pkl']
