# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, make_scorer
from sklearn.feature_selection import SelectKBest, f_classif
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import joblib
import os

# %%
# x_train_full = pd.read_csv("data/processed/x_train.csv")
# y_train_full = pd.read_csv("data/processed/y_train.csv")
# y = y_train_full.values.ravel()

# %%
# selector = SelectKBest(score_func=f_classif, k=12)
# selector.fit(x_train_full, y)
# top_features = x_train_full.columns[selector.get_support()]
# print(top_features)

# %%
# x = x_train_full[top_features]

# %%
# x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.2, random_state=42)

# %%
x_train = pd.read_csv("data/processed/x_train.csv")
x_test = pd.read_csv("data/processed/x_test.csv")

y_train = pd.read_csv("data/processed/y_train.csv").values.ravel()
y_test = pd.read_csv("data/processed/y_test.csv").values.ravel()

# %%
smote = SMOTE(random_state=42)
x_res, y_res = smote.fit_resample(x_train, y_train)

# %%
# scaler = StandardScaler()
# x_train = scaler.fit_transform(x_res)
# x_test = scaler.transform(x_test)

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
f1_macro = make_scorer(f1_score, average='macro')

# %%
rf_param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None],
    'random_state': [42]
}

rf_grid = GridSearchCV(RandomForestClassifier(n_jobs=-1), rf_param_grid, scoring=f1_macro, cv=cv, n_jobs=-1, verbose=2)
# rf_grid.fit(x_train, y_res)
rf_grid.fit(x_res, y_res)
rf_best = rf_grid.best_estimator_
print("\nMelhores parâmetros RF:", rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   8.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   8.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  12.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  13.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  15.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  16.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  10.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  10.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=   8.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   4.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  10.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  10.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  12.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   4.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  13.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  15.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   9.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   9.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   9.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  14.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  12.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  13.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   8.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  15.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  15.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  12.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  16.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  16.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  11.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  12.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   8.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  16.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  10.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  17.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  11.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  17.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   4.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  14.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  16.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   9.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   9.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  18.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  12.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  17.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  11.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  13.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  12.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   4.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  13.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  13.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  16.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  16.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  10.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  10.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  10.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  14.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  15.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   9.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  14.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  19.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   4.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  11.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  14.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  14.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   8.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   9.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  16.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  16.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  17.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   8.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  18.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  10.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  14.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  10.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  10.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  13.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.3s[CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.2s
#
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  11.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  13.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   8.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=   5.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   9.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   8.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=   9.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  13.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  11.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  11.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  14.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  13.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  16.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=   9.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  10.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  18.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  13.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  13.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  15.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  12.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   4.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  13.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=   9.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   7.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  10.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  10.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  11.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  13.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   9.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  14.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  13.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   5.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  10.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   6.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=   9.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  14.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  20.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  20.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  20.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  12.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=   6.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  13.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  12.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   7.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=   9.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  15.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  12.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  20.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  11.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  10.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  11.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  12.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=   8.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  14.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  17.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   5.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  11.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  18.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  11.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  10.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   6.3s[CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  10.9s
#
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  10.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=   8.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  13.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=   4.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  17.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   5.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  17.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time=  18.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=   9.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=   8.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  12.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time=  11.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   7.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=   4.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  14.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   6.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   5.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=   9.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  10.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=   9.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   3.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   8.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  12.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=   6.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  19.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time=  19.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time=  12.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  14.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   8.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   8.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=   9.8s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  18.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  19.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time=  20.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  11.5s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  12.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  14.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=  11.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=  13.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  17.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  18.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=  13.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=  18.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=  14.9s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  21.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  20.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  23.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=  11.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  22.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=  10.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  20.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  26.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42; total time=  25.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=  23.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=  24.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42; total time=  25.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  16.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  25.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  30.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  30.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  15.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  17.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time=  43.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  35.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  57.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  57.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  35.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  59.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  54.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  17.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time=  56.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  15.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  16.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  47.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  43.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time=  43.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  23.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  24.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  18.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  10.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  26.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  22.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  22.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  38.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  20.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  34.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time=  37.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  23.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  23.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  28.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  45.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  13.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  26.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  47.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  51.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time=  28.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time=  53.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  23.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  20.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  14.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  37.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  20.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  44.8s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  24.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  13.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  49.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  30.7s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  15.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  31.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  34.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time=  35.0s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  53.5s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time=  52.6s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  14.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  13.3s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  15.9s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  47.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  48.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  44.1s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time=  49.2s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  16.4s
# [CV] END max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time=  30.2s
# ...
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  49.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42; total time= 2.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  41.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.5min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  34.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  33.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=  41.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=42; total time= 2.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  38.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  40.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  37.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  41.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100, random_state=42; total time=  44.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time= 2.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time= 2.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time= 2.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time= 2.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  45.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  37.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  40.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  39.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100, random_state=42; total time=  39.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time= 2.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=42; total time= 2.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  44.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.2min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.2min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  42.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  43.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  42.9s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100, random_state=42; total time=  47.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time= 2.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.8min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time= 2.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300, random_state=42; total time= 2.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  41.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  33.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  38.0s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  46.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100, random_state=42; total time=  32.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time= 1.2min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time= 2.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time= 2.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300, random_state=42; total time= 2.0min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  48.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  36.5s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  43.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  39.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100, random_state=42; total time=  45.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.8min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time= 2.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300, random_state=42; total time= 1.9min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.2min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.2min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  32.2s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200, random_state=42; total time= 1.1min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  29.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  21.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  22.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100, random_state=42; total time=  24.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.4min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.2min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  41.8s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300, random_state=42; total time= 1.3min
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  41.7s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  38.4s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  37.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200, random_state=42; total time=  36.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  35.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  40.6s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  40.1s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  38.3s
# [CV] END max_depth=15, max_features=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300, random_state=42; total time=  32.6s
#
# Melhores parâmetros RF: {'max_depth': 15, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200, 'random_state': 42}

# %%
joblib.dump(rf_best, "models/rf.pkl")
# Out:
# ['models/rf.pkl']

# %%
lr_param_grid = {
    'C': [0.01, 0.1, 1, 10],
    'solver': ['lbfgs','liblinear'],
    'max_iter': [1000],
    'random_state': [42]
}

lr_grid = GridSearchCV(LogisticRegression(), lr_param_grid, scoring=f1_macro, cv=cv, n_jobs=-1, verbose=2)
# lr_grid.fit(x_train, y_res)
lr_grid.fit(x_res, y_res)
lr_best = lr_grid.best_estimator_
print("\nMelhores parâmetros LR:", lr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=0.01, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END ..C=1, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=0.1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END .C=10, max_iter=1000, random_state=42, solver=lbfgs; total time=   0.1s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=1, max_iter=1000, random_state=42, solver=liblinear; total time=   0.3s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.2s
# [CV] END C=10, max_iter=1000, random_state=42, solver=liblinear; total time=   0.1s
#
# Melhores parâmetros LR: {'C': 0.01, 'max_iter': 1000, 'random_state': 42, 'solver': 'lbfgs'}

# %%
joblib.dump(lr_best, "models/lr.pkl")
# Out:
# ['models/lr.pkl']

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Random Forest
rf_pred_train = rf_best.predict(x_res)
print("\nRandom Forest - Classification Report (Treino)")
print(classification_report(y_res, rf_pred_train))
print("Confusion Matrix (Treino):")
print(confusion_matrix(y_res, rf_pred_train))

# Logistic Regression
lr_pred_train = lr_best.predict(x_res)
print("\nLogistic Regression - Classification Report (Treino)")
print(classification_report(y_res, lr_pred_train))
print("Confusion Matrix (Treino):")
print(confusion_matrix(y_res, lr_pred_train))
# Out:
# Random Forest - Classification Report (Treino)
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.92     17402
#            1       0.92      0.91      0.92     17402
#
#     accuracy                           0.92     34804
#    macro avg       0.92      0.92      0.92     34804
# weighted avg       0.92      0.92      0.92     34804
#
# Confusion Matrix (Treino):
# [[16069  1333]
#  [ 1499 15903]]
#
# Logistic Regression - Classification Report (Treino)
#               precision    recall  f1-score   support
#
#            0       0.68      0.80      0.73     17402
#            1       0.76      0.62      0.68     17402
#
#     accuracy                           0.71     34804
#    macro avg       0.72      0.71      0.71     34804
# weighted avg       0.72      0.71      0.71     34804
#
# Confusion Matrix (Treino):
# [[13915  3487]
#  [ 6631 10771]]

# %%
# Random Forest - Teste
rf_pred_test = rf_best.predict(x_test)
print("\nRandom Forest - Classification Report (Teste)")
print(classification_report(y_test, rf_pred_test))
print("Confusion Matrix (Teste):")
print(confusion_matrix(y_test, rf_pred_test))

# Logistic Regression - Teste
lr_pred_test = lr_best.predict(x_test)
print("\nLogistic Regression - Classification Report (Teste)")
print(classification_report(y_test, lr_pred_test))
print("Confusion Matrix (Teste):")
print(confusion_matrix(y_test, lr_pred_test))
# Out:
# Random Forest - Classification Report (Teste)
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84      4350
#            1       0.48      0.54      0.51      1264
#
#     accuracy                           0.76      5614
#    macro avg       0.67      0.68      0.68      5614
# weighted avg       0.77      0.76      0.77      5614
#
# Confusion Matrix (Teste):
# [[3601  749]
#  [ 581  683]]
#
# Logistic Regression - Classification Report (Teste)
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83      4350
#            1       0.46      0.59      0.52      1264
#
#     accuracy                           0.75      5614
#    macro avg       0.67      0.70      0.68      5614
# weighted avg       0.78      0.75      0.76      5614
#
# Confusion Matrix (Teste):
# [[3480  870]
#  [ 513  751]]
